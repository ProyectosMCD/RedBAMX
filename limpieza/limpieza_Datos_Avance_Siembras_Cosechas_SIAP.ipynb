# %% [markdown]
# # Limpieza de datos de produccion mensual agricola de la pagina del SIAP

# %% [markdown]
# Una vez que tengamos los datos en archivos CSV, realizaremos una pequeña exploración para llevar a cabo una limpieza sencilla. Esto implicará identificar datos faltantes, buscar instancias duplicadas y asegurarnos de que el tipo de dato de las columnas sea coherente.

# %% [markdown]
# ### Librerías

# %%
import pandas as pd
import numpy as np
import os

# %%
def custom_to_float(value):
    '''
    Función que transformá cadenas de caracteres que son 
    números separados por comas en flotantes.
    '''
    if isinstance(value, str):
        return float(value.replace(',', ''))
    elif isinstance(value, (int, float)):
        return float(value)
    else:
        return None

# %%
def update_df_SIAP(file_SIAP, df_new, replace = False):
    '''
    Función para actualizar nuestra base de datos del SIAP,
    si no existe se crea con el data frame proporcionado.
    Si quieres reemplazar el archivo haz replace = True.
    '''

    if replace:
        os.remove(file_SIAP)

    if not os.path.exists(file_SIAP):
        df_new.to_csv(file_SIAP, index=False)
    else:
        df_new.to_csv(file_SIAP, mode='a', header=False, index=False)

# %% [markdown]
# Empezamos leyendo cada uno de los archivos y concatenándolos en un data frame

# %%
request_dict = {
  'anio': ['2020','2021','2022','2023'],
  'mes': ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto',
          'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'],
  'ciclo': ['Ciclicos - Perennes'],
  'modalidad': ['Riego + Temporal'],
  'cultivo': ['Tomate rojo (jitomate)', 'Chile verde', 'Limón', 'Pepino', 'Plátano', 'Mango', 
              'Garbanzo grano', 'Brócoli', 'Cebolla', 'Sandía', 'Papaya', 'Calabacita', 'Lechuga', 
              'Tomate verde', 'Espárrago', 'Frambuesa', 'Nopalitos', 'Nuez', 'Fresa', 'Toronja (pomelo)', 
              'Zarzamora', 'Piña', 'Coliflor', 'Frijol', 'Berenjena', 'Uva', 'Guayaba', 'Naranja', 
              'Papa', 'Melón', 'Manzana', 'Pera', 'Durazno'
              ]
}

directory = '../descarga/datosSIAP'
df_temp = pd.DataFrame()

for anio in request_dict['anio']:

  for mes in request_dict['mes']:

    for ciclo in request_dict['ciclo']:

      for modalidad in request_dict['modalidad']:
        
        for cultivo in request_dict['cultivo']:    
          
          try:

            df = pd.read_csv(os.path.join(directory,(f"{anio.replace(' ', '')}_{mes.replace(' ', '')}" +
            f"_{ciclo.replace(' ', '')}_{modalidad.replace(' ', '')}" +
            f"_{cultivo.replace(' ', '')}.csv")))
          
            if df_temp.empty:
              df_temp = df
            else:
              df_temp = pd.concat([df_temp, df], axis=0)

          except Exception as e:
            print(f"Failed: {str(e)}")
            continue
            
df_temp = df_temp.reset_index(drop=True)

# %%
df_temp
# Out:
#          Año         Mes                Ciclo         Modalidad
# 0       2020       Enero  Ciclicos - Perennes  Riego + Temporal  \
# 1       2020       Enero  Ciclicos - Perennes  Riego + Temporal
# 2       2020       Enero  Ciclicos - Perennes  Riego + Temporal
# 3       2020       Enero  Ciclicos - Perennes  Riego + Temporal
# 4       2020       Enero  Ciclicos - Perennes  Riego + Temporal
# ...      ...         ...                  ...               ...
# 355329  2023  Septiembre  Ciclicos - Perennes  Riego + Temporal
# 355330  2023  Septiembre  Ciclicos - Perennes  Riego + Temporal
# 355331  2023  Septiembre  Ciclicos - Perennes  Riego + Temporal
# 355332  2023  Septiembre  Ciclicos - Perennes  Riego + Temporal
# 355333  2023  Septiembre  Ciclicos - Perennes  Riego + Temporal
#
#                        Cultivo              Entidad        Distrito
# 0       Tomate rojo (jitomate)       Aguascalientes  Aguascalientes  \
# 1       Tomate rojo (jitomate)      Baja California        Ensenada
# 2       Tomate rojo (jitomate)  Baja California Sur          Mulegé
# 3       Tomate rojo (jitomate)  Baja California Sur         Comondú
# 4       Tomate rojo (jitomate)  Baja California Sur          La Paz
# ...                        ...                  ...             ...
# 355329                 Durazno            Zacatecas       Zacatecas
# 355330                 Durazno            Zacatecas       Zacatecas
# 355331                 Durazno            Zacatecas       Zacatecas
# 355332                 Durazno            Zacatecas       Zacatecas
# 355333                 Durazno            Zacatecas           Jalpa
#
#                       Municipio Superficie(ha)_Sembrada
# 0                      Calvillo                   16.00  \
# 1                      Ensenada                   19.50
# 2                        Mulegé                   80.00
# 3                       Comondú                  127.00
# 4                        La Paz                  611.00
# ...                         ...                     ...
# 355329                   Calera                1,213.15
# 355330  General Enrique Estrada                  294.00
# 355331                Guadalupe                    7.50
# 355332                Zacatecas                   84.00
# 355333      Nochistlán de Mejía                    2.00
#
#        Superficie(ha)_Cosechada Superficie(ha)_Siniestrada Producción
# 0                          6.00                        0.0      90.00  \
# 1                          0.00                        0.0       0.00
# 2                          0.00                        0.0       0.00
# 3                          0.00                        0.0       0.00
# 4                        106.00                        0.0   4,429.76
# ...                         ...                        ...        ...
# 355329                     0.00                        0.0       0.00
# 355330                     0.00                        0.0       0.00
# 355331                     0.00                        0.0       0.00
# 355332                     0.00                        0.0       0.00
# 355333                     2.00                        0.0      14.70
#
#         Rendimiento(udm/ha)
# 0                     15.00
# 1                      0.00
# 2                      0.00
# 3                      0.00
# 4                     41.79
# ...                     ...
# 355329                 0.00
# 355330                 0.00
# 355331                 0.00
# 355332                 0.00
# 355333                 7.35
#
# [355334 rows x 13 columns]

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 355334 entries, 0 to 355333
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Año                         355334 non-null  int64
#  1   Mes                         355334 non-null  object
#  2   Ciclo                       355334 non-null  object
#  3   Modalidad                   355334 non-null  object
#  4   Cultivo                     355334 non-null  object
#  5   Entidad                     355334 non-null  object
#  6   Distrito                    355334 non-null  object
#  7   Municipio                   355334 non-null  object
#  8   Superficie(ha)_Sembrada     355334 non-null  object
#  9   Superficie(ha)_Cosechada    355334 non-null  object
#  10  Superficie(ha)_Siniestrada  355334 non-null  object
#  11  Producción                  355334 non-null  object
#  12  Rendimiento(udm/ha)         355334 non-null  float64
# dtypes: float64(1), int64(1), object(11)
# memory usage: 35.2+ MB

# %% [markdown]
# Observamos que no tenemos ningún dato faltante. Por otro lado, la columna *Superficie(ha)_Sembrada* es de tipo 'object'; sin embargo, las columnas *Superficie(ha)_Sembrada*, *Superficie(ha)_Cosechada*, *Superficie(ha)_Siniestrada*, *Producción* y *Rendimiento(udm/ha)* deben ser de tipo numérico. La razón de esta situación es la separación por comas de los números, como se muestra en la siguiente línea:

# %%
df_temp[df_temp["Municipio"] == "Villa de Cos"]
# Out:
#          Año         Mes                Ciclo         Modalidad       Cultivo
# 2235    2020       Enero  Ciclicos - Perennes  Riego + Temporal       Cebolla  \
# 2774    2020       Enero  Ciclicos - Perennes  Riego + Temporal       Lechuga
# 8602    2020     Febrero  Ciclicos - Perennes  Riego + Temporal       Cebolla
# 9176    2020     Febrero  Ciclicos - Perennes  Riego + Temporal       Lechuga
# 15222   2020       Marzo  Ciclicos - Perennes  Riego + Temporal       Cebolla
# ...      ...         ...                  ...               ...           ...
# 350056  2023  Septiembre  Ciclicos - Perennes  Riego + Temporal       Lechuga
# 350593  2023  Septiembre  Ciclicos - Perennes  Riego + Temporal  Tomate verde
# 351616  2023  Septiembre  Ciclicos - Perennes  Riego + Temporal      Coliflor
# 353354  2023  Septiembre  Ciclicos - Perennes  Riego + Temporal        Frijol
# 354242  2023  Septiembre  Ciclicos - Perennes  Riego + Temporal          Papa
#
#           Entidad   Distrito     Municipio Superficie(ha)_Sembrada
# 2235    Zacatecas  Zacatecas  Villa de Cos                  185.00  \
# 2774    Zacatecas  Zacatecas  Villa de Cos                   85.00
# 8602    Zacatecas  Zacatecas  Villa de Cos                  185.00
# 9176    Zacatecas  Zacatecas  Villa de Cos                   85.00
# 15222   Zacatecas  Zacatecas  Villa de Cos                  290.00
# ...           ...        ...           ...                     ...
# 350056  Zacatecas  Zacatecas  Villa de Cos                  390.00
# 350593  Zacatecas  Zacatecas  Villa de Cos                  148.80
# 351616  Zacatecas  Zacatecas  Villa de Cos                    73.0
# 353354  Zacatecas  Zacatecas  Villa de Cos                3,939.10
# 354242  Zacatecas  Zacatecas  Villa de Cos                  390.10
#
#        Superficie(ha)_Cosechada Superficie(ha)_Siniestrada Producción
# 2235                       0.00                        0.0       0.00  \
# 2774                       0.00                        0.0       0.00
# 8602                       0.00                        0.0       0.00
# 9176                       0.00                        0.0       0.00
# 15222                      0.00                        0.0       0.00
# ...                         ...                        ...        ...
# 350056                   349.00                        0.0   7,888.18
# 350593                   125.00                        0.0   4,865.00
# 351616                     52.0                        0.0   1,710.80
# 353354                 1,371.00                     754.50   1,797.35
# 354242                   303.00                        0.0  12,726.00
#
#         Rendimiento(udm/ha)
# 2235                   0.00
# 2774                   0.00
# 8602                   0.00
# 9176                   0.00
# 15222                  0.00
# ...                     ...
# 350056                22.60
# 350593                38.92
# 351616                32.90
# 353354                 1.31
# 354242                42.00
#
# [243 rows x 13 columns]

# %% [markdown]
# Simplemente quitamos las comas de todos los números de estas columnas.

# %%
numeric_columns = ["Superficie(ha)_Sembrada", "Superficie(ha)_Cosechada", "Superficie(ha)_Siniestrada",
                   "Producción", "Rendimiento(udm/ha)"]
df_temp[numeric_columns] = df_temp[numeric_columns].applymap(custom_to_float)

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 355334 entries, 0 to 355333
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Año                         355334 non-null  int64
#  1   Mes                         355334 non-null  object
#  2   Ciclo                       355334 non-null  object
#  3   Modalidad                   355334 non-null  object
#  4   Cultivo                     355334 non-null  object
#  5   Entidad                     355334 non-null  object
#  6   Distrito                    355334 non-null  object
#  7   Municipio                   355334 non-null  object
#  8   Superficie(ha)_Sembrada     355334 non-null  float64
#  9   Superficie(ha)_Cosechada    355334 non-null  float64
#  10  Superficie(ha)_Siniestrada  355334 non-null  float64
#  11  Producción                  355334 non-null  float64
#  12  Rendimiento(udm/ha)         355334 non-null  float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 35.2+ MB

# %%
df_temp[df_temp["Municipio"] == "Villa de Cos"]
# Out:
#          Año         Mes                Ciclo         Modalidad       Cultivo
# 2235    2020       Enero  Ciclicos - Perennes  Riego + Temporal       Cebolla  \
# 2774    2020       Enero  Ciclicos - Perennes  Riego + Temporal       Lechuga
# 8602    2020     Febrero  Ciclicos - Perennes  Riego + Temporal       Cebolla
# 9176    2020     Febrero  Ciclicos - Perennes  Riego + Temporal       Lechuga
# 15222   2020       Marzo  Ciclicos - Perennes  Riego + Temporal       Cebolla
# ...      ...         ...                  ...               ...           ...
# 350056  2023  Septiembre  Ciclicos - Perennes  Riego + Temporal       Lechuga
# 350593  2023  Septiembre  Ciclicos - Perennes  Riego + Temporal  Tomate verde
# 351616  2023  Septiembre  Ciclicos - Perennes  Riego + Temporal      Coliflor
# 353354  2023  Septiembre  Ciclicos - Perennes  Riego + Temporal        Frijol
# 354242  2023  Septiembre  Ciclicos - Perennes  Riego + Temporal          Papa
#
#           Entidad   Distrito     Municipio  Superficie(ha)_Sembrada
# 2235    Zacatecas  Zacatecas  Villa de Cos                    185.0  \
# 2774    Zacatecas  Zacatecas  Villa de Cos                     85.0
# 8602    Zacatecas  Zacatecas  Villa de Cos                    185.0
# 9176    Zacatecas  Zacatecas  Villa de Cos                     85.0
# 15222   Zacatecas  Zacatecas  Villa de Cos                    290.0
# ...           ...        ...           ...                      ...
# 350056  Zacatecas  Zacatecas  Villa de Cos                    390.0
# 350593  Zacatecas  Zacatecas  Villa de Cos                    148.8
# 351616  Zacatecas  Zacatecas  Villa de Cos                     73.0
# 353354  Zacatecas  Zacatecas  Villa de Cos                   3939.1
# 354242  Zacatecas  Zacatecas  Villa de Cos                    390.1
#
#         Superficie(ha)_Cosechada  Superficie(ha)_Siniestrada  Producción
# 2235                         0.0                         0.0        0.00  \
# 2774                         0.0                         0.0        0.00
# 8602                         0.0                         0.0        0.00
# 9176                         0.0                         0.0        0.00
# 15222                        0.0                         0.0        0.00
# ...                          ...                         ...         ...
# 350056                     349.0                         0.0     7888.18
# 350593                     125.0                         0.0     4865.00
# 351616                      52.0                         0.0     1710.80
# 353354                    1371.0                       754.5     1797.35
# 354242                     303.0                         0.0    12726.00
#
#         Rendimiento(udm/ha)
# 2235                   0.00
# 2774                   0.00
# 8602                   0.00
# 9176                   0.00
# 15222                  0.00
# ...                     ...
# 350056                22.60
# 350593                38.92
# 351616                32.90
# 353354                 1.31
# 354242                42.00
#
# [243 rows x 13 columns]

# %% [markdown]
# Por último, vemos que no tenemos instancias repetidas.

# %%
df_temp[df_temp.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Año, Mes, Ciclo, Modalidad, Cultivo, Entidad, Distrito, Municipio, Superficie(ha)_Sembrada, Superficie(ha)_Cosechada, Superficie(ha)_Siniestrada, Producción, Rendimiento(udm/ha)]
# Index: []

# %% [markdown]
# Ahora que estos datos están de la forma que queremos, podemos agregarlos a uno data frame general con todos los datos previamente limpiados.

# %%
file_SIAP = "SIAP.csv"
update_df_SIAP(file_SIAP, df_temp, replace=True)
